# %%
import pandas as pd
pd.Series?
animals = ['Tiger', 'Bear', 'Moose']
pd.Series(animals)

# %%
import pandas as pd

#pd.Series? # Gives an explanation of pandas

sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
# s = pd.Series(sports)
# s.index

s = pd.Series(sports, index=['Golf', 'Sumo', 'Hockey'])
s

# %%
import pandas as pd
import numpy as np

s = pd.Series(np.random.randint(0,1000,10000)) # 10000 random integers between 0 and 1000.
s.head()
len(s)

# %%timeit np.sum(s)

# %%
import pandas as pd

purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])

# df.head()
# df.loc['Store 2']

# df.Cost = 0.8*df.Cost # This is how you write specific elements.
# df.drop('Store 1')

copydf = df.copy()
# copydf.drop(['Name'], axis = 1) # Doesn't change copydf !!!
del copydf['Name'] # This changes copydf !!!
copydf

# %%
# !cat olympics.csv # Opens up the csv file for a quick read.

# %%
import pandas as pd
df = pd.read_csv('olympics.csv')

df = pd.read_csv('olympics.csv', index_col = 0, skiprows=1)
# ^Parameters are which column is going to be the index and which row is going to be the header.

# df.head()
# df.columns # Stores the names of all the columns

for col in df.columns: # Iterating over all columns
    if col[:2]=='01': # Iterating over the characters in one column label
        df.rename(columns={col:'Gold' + col[4:]}, inplace=True) # Rewriting the specific column label only
    if col[:2]=='02':
        df.rename(columns={col:'Silver' + col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze' + col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#' + col[1:]}, inplace=True)
        
# inplace=True tells pandas to update the DataFrame directly.

# onlygold = df.where(df['Gold']>0)
# Sets the false entries to NaN.

# onlygold.head()
# onlygold['Gold'].count() # Gives 100
# df['Gold'].count() # Gives 147

# So the Nan entries are not counted in onlygold.

df['country'] = df.index
df = df.set_index('Gold')
df.head()

# %%
import pandas as pd

purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])

df = df.set_index([df.index, 'Name'])
df.index.names = ['Location', 'Name'] # Rewriting index name!
df = df.append(pd.Series(data={'Cost': 3.00, 'Item Purchased': 'Kitty Food'}, name=('Store 2', 'Kevyn')))
df

# %%
import pandas as pd
df = pd.read_csv('log.csv')
df = df.set_index('time')
df = df.sort_index()

df = df.reset_index()
df = df.set_index(['time','user'])
df = df.fillna(method='ffill')
# ^Propagates/copies the last valid entry before NaN to the following entries upto the next valid entry
df.head()

# %%
import pandas as pd

df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)
        
#df.drop('Totals')
df.head()

# %%
import pandas as pd

staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])

staff_df = staff_df.set_index('Name')

student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])

student_df = student_df.set_index('Name')

pd.merge(staff_df, student_df, left_index=True,right_on='')

# %%
# ENERGY:

import pandas as pd
import numpy as np

energy = pd.read_excel("Energy Indicators.xls",skip_footer=38,skip_header=1,skiprows=16) # Skip header and footer

#energy.head()
#type(energy) #DataFrame

energy.drop(energy.columns[[0,1]],axis=1,inplace=True) # Drop first 2 columns

energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']

energy.dropna() # Drop rows with NaN values.

energy['Country'] = energy['Country'].str.replace(r'\(.*\)', '') # Remove contents within parenthesis.
energy['Country'] = energy['Country'].str.replace('\d+', '') # Remove digits from names

# Turn blank values into NaN
for col in energy:
    energy[col] = energy[col].replace('...',np.nan)
    
energy['Country'] = energy['Country'].str.replace('Republic of Korea','South Korea')
energy['Country'] = energy['Country'].str.replace('United States of America','United States')
energy['Country'] = energy['Country'].str.replace('United Kingdom of Great Britain and Northern Ireland','United Kingdom')
energy['Country'] = energy['Country'].str.replace('China, Hong Kong Special Administrative Region','Hong Kong')

#type(energy['Energy Supply'])
energy

# %%
# GDP:

import pandas as pd
import numpy as np

GDP = pd.read_csv('world_bank.csv', skiprows=3) # Skip header

# Make first row the column names
new_header = GDP.iloc[0]
GDP = GDP[1:]
GDP.columns = new_header

#GDP = GDP.rename(index=str,columns = {"Country Name":"Country"})

GDP['Country Name'] = GDP['Country Name'].str.replace('Korea, Rep.','South Korea')
GDP['Country Name'] = GDP['Country Name'].str.replace('Iran, Islamic Rep.','Iran')
GDP['Country Name'] = GDP['Country Name'].str.replace('Hong Kong SAR, China','Hong Kong')

# Change column name from 'Country Name' to 'Country' for merging 3 files on country name.
names = GDP.columns.tolist()
names[names.index('Country Name')] = 'Country'
GDP.columns = names

# Only keep the columns from 2006-15.
GDP = GDP.drop(GDP.iloc[:,1:50], axis=1)
GDP
# Out:
#                                                Country        2006.0  \
# 1                                                Aruba           NaN
# 2                                              Andorra  4.018196e+09
# 3                                          Afghanistan  1.030523e+10
# 4                                               Angola  5.581103e+10
# 5                                              Albania  9.771760e+09
# 6                                           Arab World  1.763824e+12
# 7                                 United Arab Emirates  2.789489e+11
# 8                                            Argentina  3.788140e+11
# 9                                              Armenia  8.679746e+09
# 10                                      American Samoa           NaN
# 11                                 Antigua and Barbuda  1.268714e+09
# 12                                           Australia  1.021939e+12
# 13                                             Austria  3.782096e+11
# 14                                          Azerbaijan  3.329047e+10
# 15                                             Burundi  1.714698e+09
# 16                                             Belgium  4.626081e+11
# 17                                               Benin  6.000596e+09
# 18                                        Burkina Faso  7.094394e+09
# 19                                          Bangladesh  9.158885e+10
# 20                                            Bulgaria  4.580943e+10
# 21                                             Bahrain  2.088961e+10
# 22                                        Bahamas, The  8.203865e+09
# 23                              Bosnia and Herzegovina  1.572365e+10
# 24                                             Belarus  4.274098e+10
# 25                                              Belize  1.285312e+09
# 26                                             Bermuda  5.932559e+09
# 27                                             Bolivia  1.644957e+10
# 28                                              Brazil  1.845080e+12
# 29                                            Barbados  4.522426e+09
# 30                                   Brunei Darussalam  1.249730e+10
# ..                                                 ...           ...
# 235  Middle East & North Africa (IDA & IBRD countries)  1.128451e+12
# 236                                        Timor-Leste  5.940000e+08
# 237                                              Tonga  3.591646e+08
# 238                            South Asia (IDA & IBRD)  1.588121e+12
# 239          Sub-Saharan Africa (IDA & IBRD countries)  1.107337e+12
# 240                                Trinidad and Tobago  2.033516e+10
# 241                                            Tunisia  3.712967e+10
# 242                                             Turkey  6.680034e+11
# 243                                             Tuvalu  2.980999e+07
# 252  4.333287e+11  4.391487e+11  4.220465e+11  3.979899e+11
# 253           NaN           NaN           NaN           NaN
# 254           NaN           NaN           NaN           NaN
# 255  1.296292e+11  1.366576e+11  1.448347e+11  1.545086e+11
# 256  7.218245e+08  7.360383e+08  7.529991e+08           NaN
# 257  1.100864e+10  1.053747e+10  1.042246e+10  1.171414e+10
# 258  6.937886e+13  7.104232e+13  7.291072e+13  7.470901e+13
# 259  6.975356e+08  6.840462e+08  6.922284e+08  7.035448e+08
# 260  2.689160e+10  2.800914e+10           NaN           NaN
# 261  3.960071e+11  4.047682e+11  4.110369e+11  4.163117e+11
# 262  2.350200e+10  2.550050e+10  2.778776e+10  2.970961e+10
# 263  2.302438e+10  2.420595e+10  2.542227e+10  2.624127e+10
# 264  1.165789e+10  1.218064e+10  1.264939e+10  1.278517e+10
#
# [264 rows x 11 columns]

# %%
# SCIMEN:

import pandas as pd
import numpy as np

ScimEn = pd.read_excel('scimagojr-3.xlsx')
ScimEn = ScimEn[:15] # Only top 15 countries
ScimEn
# Out:
#     Rank             Country  Documents  Citable documents  Citations  \
# 0      1               China     127050             126767     597237
# 1      2       United States      96661              94747     792274
# 2      3               Japan      30504              30287     223024
# 3      4      United Kingdom      20944              20357     206091
# 4      5  Russian Federation      18534              18301      34266
# 5      6              Canada      17899              17620     215003
# 6      7             Germany      17027              16831     140566
# 7      8               India      15005              14841     128763
# 8      9              France      13153              12973     130632
# 9     10         South Korea      11983              11923     114675
# 10    11               Italy      10964              10794     111850
# 11    12               Spain       9428               9330     123336
# 12    13                Iran       8896               8819      57470
# 13    14           Australia       8831               8725      90765
# 14    15              Brazil       8668               8596      60702
#
#     Self-citations  Citations per document  H index
# 0           411683                    4.70      138
# 1           265436                    8.20      230
# 2            61554                    7.31      134
# 3            37874                    9.84      139
# 4            12422                    1.85       57
# 5            40930                   12.01      149
# 6            27426                    8.26      126
# 7            37209                    8.58      115
# 8            28601                    9.93      114
# 9            22595                    9.57      104
# 10           26661                   10.20      106
# 11           23964                   13.08      115
# 12           19125                    6.46       72
# 13           15606                   10.28      107
# 14           14396                    7.00       86

# %%
# MERGING ENERGY, GDP AND SCIMEN:

import pandas as pd
import numpy as np

# ENERGY:

energy = pd.read_excel("Energy Indicators.xls",skip_footer=38,skip_header=1,skiprows=16) # Skip header and footer

#energy.head()
#type(energy) #DataFrame

energy.drop(energy.columns[[0,1]],axis=1,inplace=True) # Drop first 2 columns

energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']

energy.dropna() # Drop rows with NaN values.

energy['Country'] = energy['Country'].str.replace(r'\(.*\)', '') # Remove contents within parenthesis.
energy['Country'] = energy['Country'].str.replace('\d+', '') # Remove digits from names

# Turn blank values into NaN
for col in energy:
    energy[col] = energy[col].replace('...',np.nan)
    
energy['Country'] = energy['Country'].str.replace('Republic of Korea','South Korea')
energy['Country'] = energy['Country'].str.replace('United States of America','United States')
energy['Country'] = energy['Country'].str.replace('United Kingdom of Great Britain and Northern Ireland','United Kingdom')
energy['Country'] = energy['Country'].str.replace('China, Hong Kong Special Administrative Region','Hong Kong')


# GDP:

GDP = pd.read_csv('world_bank.csv', skiprows=3) # Skip header

# Make first row the column names
new_header = GDP.iloc[0]
GDP = GDP[1:]
GDP.columns = new_header

#GDP = GDP.rename(index=str,columns = {"Country Name":"Country"})

GDP['Country Name'] = GDP['Country Name'].str.replace('Korea, Rep.','South Korea')
GDP['Country Name'] = GDP['Country Name'].str.replace('Iran, Islamic Rep.','Iran')
GDP['Country Name'] = GDP['Country Name'].str.replace('Hong Kong SAR, China','Hong Kong')

# Change column name from 'Country Name' to 'Country' for merging 3 files on country name.
names = GDP.columns.tolist()
names[names.index('Country Name')] = 'Country'
GDP.columns = names

# Only keep the columns from 2006-15. Drop column number 1 to 50. Don't need country code, etc.
GDP = GDP.drop(GDP.iloc[:,1:50], axis=1)
#GDP

# SCIMEN:

ScimEn = pd.read_excel('scimagojr-3.xlsx')
#ScimEn = ScimEn[:15] # Only top 15 countries
#ScimEn

# MERGING:

master = pd.merge(ScimEn,energy,how='outer',left_on='Country',right_on='Country')
master1 = pd.merge(master,GDP,how='outer',left_on='Country',right_on='Country')

master1 = master1[:15] # Limit to top 15 entries.

master1.set_index('Country')
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                1.0   127050.0           126767.0   597237.0
# United States        2.0    96661.0            94747.0   792274.0
# Japan                3.0    30504.0            30287.0   223024.0
# United Kingdom       4.0    20944.0            20357.0   206091.0
# Russian Federation   5.0    18534.0            18301.0    34266.0
# Canada               6.0    17899.0            17620.0   215003.0
# Germany              7.0    17027.0            16831.0   140566.0
# India                8.0    15005.0            14841.0   128763.0
# France               9.0    13153.0            12973.0   130632.0
# South Korea         10.0    11983.0            11923.0   114675.0
# Italy               11.0    10964.0            10794.0   111850.0
# Spain               12.0     9428.0             9330.0   123336.0
# Iran                13.0     8896.0             8819.0    57470.0
# Australia           14.0     8831.0             8725.0    90765.0
# Brazil              15.0     8668.0             8596.0    60702.0
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                     411683.0                    4.70    138.0
# United States             265436.0                    8.20    230.0
# Japan                      61554.0                    7.31    134.0
# United Kingdom             37874.0                    9.84    139.0
# Russian Federation         12422.0                    1.85     57.0
# Canada                     40930.0                   12.01    149.0
# Germany                    27426.0                    8.26    126.0
# India                      37209.0                    8.58    115.0
# France                     28601.0                    9.93    114.0
# South Korea                22595.0                    9.57    104.0
# Italy                      26661.0                   10.20    106.0
# Spain                      23964.0                   13.08    115.0
# Iran                       19125.0                    6.46     72.0
# Australia                  15606.0                   10.28    107.0
# Brazil                     14396.0                    7.00     86.0
#
#                    Energy Supply Energy Supply per Capita % Renewable  \
# Country
# China                     127191                       93     19.7549
# United States              90838                      286      11.571
# Japan                      18984                      149     10.2328
# United Kingdom              7920                      124     10.6005
# Russian Federation         30709                      214     17.2887
# Canada                     10431                      296     61.9454
# Germany                    13261                      165     17.9015
# India                      33195                       26     14.9691
# France                     10597                      166     17.0203
# South Korea                11007                      221     2.27935
# Italy                       6530                      109     33.6672
# Spain                       4923                      106     37.9686
# Iran                         NaN                      NaN         NaN
# Australia                   5386                      231     11.8108
# Brazil                     12149                       59      69.648
#
#                           2006.0        2007.0        2008.0        2009.0  \
# Country
# China               3.992331e+12  4.559041e+12  4.997775e+12  5.459247e+12
# United States       1.479230e+13  1.505540e+13  1.501149e+13  1.459484e+13
# Japan               5.496542e+12  5.617036e+12  5.558527e+12  5.251308e+12
# United Kingdom      2.419631e+12  2.482203e+12  2.470614e+12  2.367048e+12
# Russian Federation  1.385793e+12  1.504071e+12  1.583004e+12  1.459199e+12
# Canada              1.564469e+12  1.596740e+12  1.612713e+12  1.565145e+12
# Germany             3.332891e+12  3.441561e+12  3.478809e+12  3.283340e+12
# India               1.265894e+12  1.374865e+12  1.428361e+12  1.549483e+12
# France              2.607840e+12  2.669424e+12  2.674637e+12  2.595967e+12
# South Korea         9.410199e+11  9.924316e+11  1.020510e+12  1.027730e+12
# Italy               2.202170e+12  2.234627e+12  2.211154e+12  2.089938e+12
# Spain               1.414823e+12  1.468146e+12  1.484530e+12  1.431475e+12
# Iran                3.895523e+11  4.250646e+11  4.289909e+11  4.389208e+11
# Australia           1.021939e+12  1.060340e+12  1.099644e+12  1.119654e+12
# Brazil              1.845080e+12  1.957118e+12  2.056809e+12  2.054215e+12
#
#                           2010.0        2011.0        2012.0        2013.0  \
# Country
# China               6.039659e+12  6.612490e+12  7.124978e+12  7.672448e+12
# United States       1.496437e+13  1.520402e+13  1.554216e+13  1.577367e+13
# Japan               5.498718e+12  5.473738e+12  5.569102e+12  5.644659e+12
# United Kingdom      2.403504e+12  2.450911e+12  2.479809e+12  2.533370e+12
# Russian Federation  1.524917e+12  1.589943e+12  1.645876e+12  1.666934e+12
# Canada              1.613406e+12  1.664087e+12  1.693133e+12  1.730688e+12
# Germany             3.417298e+12  3.542371e+12  3.556724e+12  3.567317e+12
# India               1.708459e+12  1.821872e+12  1.924235e+12  2.051982e+12
# France              2.646995e+12  2.702032e+12  2.706968e+12  2.722567e+12
# South Korea         1.094499e+12  1.134796e+12  1.160809e+12  1.194429e+12
# Italy               2.125185e+12  2.137439e+12  2.077184e+12  2.040871e+12
# Spain               1.431673e+12  1.417355e+12  1.380216e+12  1.357139e+12
# Iran                4.677902e+11  4.853309e+11  4.532569e+11  4.445926e+11
# Australia           1.142251e+12  1.169431e+12  1.211913e+12  1.241484e+12
# Brazil              2.208872e+12  2.295245e+12  2.339209e+12  2.409740e+12
#
#                           2014.0        2015.0
# Country
# China               8.230121e+12  8.797999e+12
# United States       1.615662e+13  1.654857e+13
# Japan               5.642884e+12  5.669563e+12
# United Kingdom      2.605643e+12  2.666333e+12
# Russian Federation  1.678709e+12  1.616149e+12
# Canada              1.773486e+12  1.792609e+12
# Germany             3.624386e+12  3.685556e+12
# India               2.200617e+12  2.367206e+12
# France              2.729632e+12  2.761185e+12
# South Korea         1.234340e+12  1.266580e+12
# Italy               2.033868e+12  2.049316e+12
# Spain               1.375605e+12  1.419821e+12
# Iran                4.639027e+11           NaN
# Australia           1.272520e+12  1.301251e+12
# Brazil              2.412231e+12  2.319423e+12
